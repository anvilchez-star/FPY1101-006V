# %% [markdown]
# <a href="https://colab.research.google.com/github/anvilchez-star/FPY1101-006V/blob/main/Ejercicios_diccionario%2Clista_y_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 1
cant_premium= 0
cant_estandar= 0
print("---Centro de Distrubuciones Industrial---")
while True:
  try:
    total_productos=int(input(" cuantos productos desea registrar :"))
    if total_productos>0:
      break
    else:
      print("cantidad invalida")
  except ValueError:
    print("cantidad invalida")

  for i in range(total_productos):
    print(f"\n---Registro del producto {i+1} de {total_productos}---")
    while True:
      sku=input("Codigo SKU:").strip()
      if len (sku)>=6 and "" not in sku:
        break
      else:
        print("Error en el codigo SKU, debe tener al menos 6 caracteres y no estar vacio")
    while True:
      try:
        valor_unitario=int(input("Valor unitario:"))
        if valor_unitario>0:
          break
        else:
          print("Error en el valor unitario, debe ser mayor a 0")
      except ValueError:
        print("Error en el valor unitario, debe ser un numero entero")
    if valor_unitario>=10000:
      cant_premium+=1
    else:
      cant_estandar+=1
print("          RESUMEN DE REGISTRO           ")
print("========================================")
print(f"Total de productos registrados: {total_productos}")
print(f"Productos Premium: {cant_premium}")
print(f"Productos Estándar: {cant_estandar}")
print("========================================")
# Out:
# ---Centro de Distrubuciones Industrial---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5035/3822233896.py in <cell line: 0>()
#       5 while True:
#       6   try:
# ----> 7     total_productos=int(input(" cuantos productos desea registrar :"))
#       8     if total_productos>0:
#       9       break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
#=============================

#SISTEMA DE GESTION DE VENTAS

#=============================



def calcula_subtotal(precio,cantidad):

  return precio*cantidad



def calcular_descuento(subtotal):

  if subtotal>=100000:

    return subtotal*0.15

  elif subtotal>=50000 and subtotal<=100000:

     return subtotal*0.10

  else:

    return 0



def calcular_iva(monto):

  return monto*0.19



def calcular_total(subtotal,descuento,iva):

  return subtotal - descuento + iva



def mostrar_resumen(producto,precio,cantidad,subtotal,descuento,iva,total):



  print("\n===RESUMEN DE COMPRA===")

  print(f"producto: {producto}")

  print(f"prcio: ${precio}")

  print(f"cantidad: {cantidad}")

  print(f"subtotal: ${subtotal}")

  print(f"descuento: ${descuento}")

  print(f"IVA: ${iva}")

  print(f"total: ${total}")
  print("=========================")
  #variable para acumular venta
  ventas_acumuladas=0
  while True:
    print("\n===Menú===")
    print("1.Registar venta")
    print("2.Ver ventas acumuladas")
    print("3.Salir")
    opcion=input("Seleccione una opcion (1/2/3):")
    try:
      opcion=int(input("ingrese opcion(1,3))
      if opcion==1:
        producto=input("Ingrese el nombre del producto:")
        precio=float(input("Ingrese el precio del producto:"))
        cantidad=int(input("Ingrese la cantidad a comprar:"))
        subtotal=calcular_subtotal(precio,cantidad)
        descuento=calcular_descuento(subtotal)
        iva=calcular_iva(subtotal)
        total=calcular_total(subtotal,descuento,iva)
        ventas_acumuladas+=total
        mostrar_resumen(producto,precio,cantidad,subtotal,descuento,iva,total)
        elif opcion==2:
            print(f"\nTotal de ventas acumuladas: {ventas_acumuladas}")
        elif opcion==3:
            print("saliendo del programa...")
            break
        else:
            print("opcion invalida")
    except ValueError:
      print("opcion invalida")
# Out:
#   File "/tmp/ipykernel_9009/2506923389.py", line 72
#     opcion=int(input("ingrese opcion(1,3))
#                      ^
# SyntaxError: unterminated string literal (detected at line 72)

# %%
inventario = []

def Registrar_libro():#Sistema de Gestión de Inventario de una Librería
    codigo = input("Ingrese codigo de libro: ")

    for libro in inventario:
        if libro ["codigo"] == codigo:
            print("Codigo ya existe!!")
            return
    titulo = input("Ingrese titulo del libro: ")
    autor = input("Ingrese el autor del libro: ")

    try:
        cantidad = int (input("Ingrese cantidad: "))
        precio = float (input("Ingrese precio: "))
    except ValueError:
        print("Error: debe ingresar valores numericos.")
        return

    libro = {
        "codigo": codigo,
        "titulo": titulo,
        "autor": autor,
        "cantidad": cantidad,
        "precio": precio
    }

    inventario.append(libro)
    print("Libro registrado correctamente.")

def Buscar_libro():
    codigo = input("Ingrese codigo a buscar: ")

    for libro in inventario:
        if libro["codigo"] == codigo:
            print("\n=== Libro Encontrado ===")
            print("Codigo: ",libro["codigo"])
            print("Titulo: ",libro["titulo"])
            print("Autor: ",libro["autor"])
            print("Cantidad: ",libro["cantidad"])
            print("Precio: ",libro["precio"])
            return
    print("Codigo no encontrado.")

def Actualizar_stock():
    codigo = input("Ingrese codigo de libro al que se desea actualizar su stock: ")

    for libro in inventario:
        if libro["codigo"] == codigo:
            try:
                Nueva_cantidad = int (input("Ingrese el nuevo stock del libro: "))
                libro ["cantidad"] = Nueva_cantidad
                print("Stock actualizado correctamente.")
            except ValueError:
                print("Error: debe ingresar un valor numerico entero.")
            return
    print("Codigo no encontrado.")

def Mostrar_inventario():
    if len(inventario) == 0:
        print("El inventario esta vacio.")
        return

    print("==== Inventario ====")
    for libro in inventario:
        print("-----------------------")
        print("Codigo:   ", libro["codigo"])
        print("Titulo:   ", libro["titulo"])
        print("Autor:    ", libro["autor"])
        print("Cantidad: ", libro["cantidad"])
        print("Precio:   ", libro["precio"])
    print("-----------------------")


def Libro_mas_caro():
    if len(inventario) == 0:
        print("El inventario esta vacio.")
        return

    Mas_caro = inventario[0]
    for libro in inventario:
        if libro ["precio"] > Mas_caro["precio"]:
            Mas_caro = libro

    print("\n=== Libro mas caro ===")
    print("Codigo:   ", Mas_caro["codigo"])
    print("Titulo:   ", Mas_caro["titulo"])
    print("Autor:    ", Mas_caro["autor"])
    print("Cantidad: ", Mas_caro["cantidad"])
    print("Precio:   ", Mas_caro["precio"])


def Eliminar_libro():
    codigo = input ("Ingrese el codigo del libro a eliminar: ")
    for libro in inventario:
        if libro ["codigo"] == codigo:
            inventario.remove(libro)
            print("Libro eliminado correctamente.")
            return
    print("Codigo no encontrado.")

def Valor_total_inventario():
    total = 0

    for libro in inventario:
        total = total + libro["cantidad"]*libro["precio"]
    print(f"Valor total del inventario es:{total}")


while True:
    print("\n===== LIBRERÍA =====")
    print("1. Registrar libro")
    print("2. Buscar libro")
    print("3. Actualizar stock")
    print("4. Mostrar inventario")
    print("5. Mostrar libro más caro")
    print("6. Eliminar libro")
    print("7. Mostrar el valor total del inventario")
    print("8. Salir")

    try:
        opcion = int(input("Seleccione una opcion (1-8): "))
        if opcion == 1:
            Registrar_libro()
        elif opcion == 2:
            Buscar_libro()
        elif opcion == 3:
            Actualizar_stock()
        elif opcion == 4:
            Mostrar_inventario()
        elif opcion == 5:
            Libro_mas_caro()
        elif opcion == 6:
            Eliminar_libro()
        elif opcion == 7:
            Valor_total_inventario()
        elif opcion == 8:
            print("Saliendo del programa...")
            break
        else:
            print("Opcion invalida, ingrese un numero entre 1 y 8.")
    except:
        print("Valor ingresado es invalido por favor ingresar un numero entero entre 1 y 8.")
# Out:
# ===== LIBRERÍA =====
# 1. Registrar libro
# 2. Buscar libro
# 3. Actualizar stock
# 4. Mostrar inventario
# 5. Mostrar libro más caro
# 6. Eliminar libro
# 7. Mostrar el valor total del inventario
# 8. Salir
# Valor ingresado es invalido por favor ingresar un numero entero entre 1 y 8.
#
# ===== LIBRERÍA =====
# 1. Registrar libro
# 2. Buscar libro
# 3. Actualizar stock
# 4. Mostrar inventario
# 5. Mostrar libro más caro
# 6. Eliminar libro
# 7. Mostrar el valor total del inventario
# 8. Salir
# Valor ingresado es invalido por favor ingresar un numero entero entre 1 y 8.
#
# ===== LIBRERÍA =====
# 1. Registrar libro
# 2. Buscar libro
# 3. Actualizar stock
# 4. Mostrar inventario
# 5. Mostrar libro más caro
# 6. Eliminar libro
# 7. Mostrar el valor total del inventario
# 8. Salir
# Valor ingresado es invalido por favor ingresar un numero entero entre 1 y 8.
#
# ===== LIBRERÍA =====
# 1. Registrar libro
# 2. Buscar libro
# 3. Actualizar stock
# 4. Mostrar inventario
# ...

# %%
num1=int(input("ingrese el primer numero:"))
num2=int(input("ingrese el segundo numero:"))
suma=num1+num2
print("la suma es:",suma)
# Out:
# ingrese el primer numero:5
# ingrese el segundo numero:7
# la suma es: 12

# %%
#calculadora funciones
nombre=input("ingrese su nombre:")
print("Bienvenido a nuestra calculadora",nombre)
def suma(a,b):
    return a+b

def restar(a,b):
    return a-b

def multiplicar(a,b):
    return a*b

def dividir(a,b):
    if b==0:
        return "Error : div/0"
    return a/b

#Menú principal
while True:
    print("\n===CALCULADORA===")
    print("1. Sumar")
    print("2. Restar")
    print("3. Multiplicar")
    print("4. Dividir")
    print("5. Salir")
    try:
        opcion=int(input("Seleccione una opcion (1/2/3/4/5):"))
        if opcion==5:
            print("Gracias por usar la calculadora. ¡Hasta luego!")
            break
        elif opcion>=1 and opcion<=4:
            num1=float(input("Ingrese el primer numero:"))
            num2=float(input("Ingrese el segundo numero:"))
            if opcion==1:
                resultado=suma(num1,num2)
                print("El resultado es :",resultado)
            elif opcion==2:
                resultado=restar(num1,num2)
                print("El resultado es :",resultado)
            elif opcion==3:
                resultado=multiplicar(num1,num2)
                print("El resultado es :",resultado)
            elif opcion==4:
                resultado=dividir(num1,num2)
                print("El resultado es :",resultado)
        else:
            print("Opcion no valida")
    except ValueError:
        print("Error: Ingrese un valor numerico.")
# Out:
# ingrese su nombre:Anthony Lenin
# Bienvenido a nuestra calculadora Anthony Lenin
#
# ===CALCULADORA===
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dividir
# 5. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1384/2882694810.py in <cell line: 0>()
#      25     print("5. Salir")
#      26     try:
# ---> 27         opcion=int(input("Seleccione una opcion (1/2/3/4/5):"))
#      28         if opcion==5:
#      29             print("Gracias por usar la calculadora. ¡Hasta luego!")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
diccionario = {"nombre": "cesar Huispe", "fonos": [983645278, 923647856, 923746578],"activo": True}
print("nombre:",diccionario["nombre"])

# %%
#ejercicio 1 de listas
numero=[1,2,3,4,5]
frutas=["manzana","pera","naranja"]
lista_vacia=[]
print(numero)
print(frutas)
print(lista_vacia)

# %%
#ejercicio 2 listas
frutas=["manzana","pera","uva","naranaja"]


print(frutas[0])
print(frutas[-1])  #el -1 es para saber el ultimo valor de la lista
print(frutas[1:3])
# Out:
# manzana
# naranaja
# ['pera', 'uva']

# %%
#ejercicio 3  lista
frutas=["manzana","pera"]
frutas.append("uva")#append es para agregar algo dentro de la variable
frutas.insert(1,"naranja")
frutas.remove("pera") #remove:elimina el elemento
frutas.pop(0) #pop:elimina el elemento en la posicion especificada
print(frutas)
# Out:
# ['naranja', 'uva']

# %%
#ejercicio 4 lista
frutas=["manzana","pera","uva","naranja"]
for fruta in frutas:
  print(fruta)

  #recorrido con numero de poscision
  for i,fruta in enumerate(frutas): #enumerate entrega la poscicion  y su valor
    print(i,frutas)
# Out:
# manzana
# 0 ['manzana', 'pera', 'uva', 'naranja']
# 1 ['manzana', 'pera', 'uva', 'naranja']
# 2 ['manzana', 'pera', 'uva', 'naranja']
# 3 ['manzana', 'pera', 'uva', 'naranja']
# pera
# 0 ['manzana', 'pera', 'uva', 'naranja']
# 1 ['manzana', 'pera', 'uva', 'naranja']
# 2 ['manzana', 'pera', 'uva', 'naranja']
# 3 ['manzana', 'pera', 'uva', 'naranja']
# uva
# 0 ['manzana', 'pera', 'uva', 'naranja']
# 1 ['manzana', 'pera', 'uva', 'naranja']
# 2 ['manzana', 'pera', 'uva', 'naranja']
# 3 ['manzana', 'pera', 'uva', 'naranja']
# naranja
# 0 ['manzana', 'pera', 'uva', 'naranja']
# 1 ['manzana', 'pera', 'uva', 'naranja']
# 2 ['manzana', 'pera', 'uva', 'naranja']
# 3 ['manzana', 'pera', 'uva', 'naranja']

# %%
#ejercicio 6 lista
cuadros=[n**2 for n in range(5)]
print(cuadrados)
pares=[n for n in range(10) if n%2==0]
print(pares)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1537/2914281548.py in <cell line: 0>()
#       1 #ejercicio 6 lista
#       2 cuadros=[n**2 for n in range(5)]
# ----> 3 print(cuadrados)
#       4 pares=[n for n in range(10) if n%2==0]
#       5 print(pares)
#
# NameError: name 'cuadrados' is not defined

# %%
def funcion_sencilla():
  print("hola, soy una funcion senciila")
  funcion_sencilla()

# %%
def suma():
  num1=3
  num2=5
  return(num1+num2)
  print("la suma es",suma())

# %%
#funcion con argumento y sin retorno
def suma(a,b):
  sumar=a+b
  print(f"la suma de los argumentos es:{sumar}")

# %%
def suma(a,b):
  sumar=a+b
  return (sumar)
  num1=int(input("ingrese el primer numero:"))
  num2=int(input("ingrese el segundo numero:"))

  print(f"la suma de los argumentos es:",suma(num1,num2))

# %%
#ejercicio 7 listas: unir y copiar listas
a=[1,2,3]
b=[4,5,6]
combinada=a+b
print(combinada)
copia= a.copy()
copia.append(99)
print(a)
print(copia)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3]
# [1, 2, 3, 99]

# %%
#ejercicio 1 de diccionarios:
persona={"nombre":"josue",
         "edad":25,
         "ciudad":"santiago"
    }
print(persona["nombre"])
print(persona["edad"])
print(persona["ciudad"])
# Out:
# josue
# 25
# santiago

# %%
#ejercicio 2 diccionario:
producto={"nombre":"Laptop","precio":800}
#agregar nuevo campo
producto["descuento"]=0.10
#modificar campo existente
producto["precio"]=720
print(producto)
# Out:
# {'nombre': 'Laptop', 'precio': 720, 'descuento': 0.1}

# %%
#ejercicio 3 diccionario:
calificaciones={"nombre_alumno":"anthony","programacion":6.2,"matematica":5.5,"ciencias":5.6,"lenguaje":4.0}
for materia,calificaciones in calificaciones.items():
  print(f"{materia}:{calificaciones}")
# Out:
# nombre_alumno:anthony
# programacion:6.2
# matematica:5.5
# ciencias:5.6
# lenguaje:4.0

# %%
#ejercicio 4 diccionario:
inventario={"manzana":20,"pera":30,"naranaja":25,}
print(list(inventario.keys()))#para motrar la lista ponemos: "list" y luego la variable en este caso seria :"inventario" y por ultimo seria los puntos el cual son tres :"keys": para mostrar solo las claves es decir las palabras
print(list(inventario.values()))
print(list(inventario.items()))
# Out:
# ['manzana', 'pera', 'naranaja']
# [20, 30, 25]
# [('manzana', 20), ('pera', 30), ('naranaja', 25)]

# %%
#ejercicio 5
temperaturas={"santiago":22,"valparaiso":18,"concepcion":20,"antofagasta":18}
for ciudad,temp in temperaturas.items():
  if temp>25:
    print(f"{ciudad}:{temperaturas} c")

# %%
#ejercico 6 diccionario;
palabras=["gato","gatos","perros","perros","cuy","cuy"]
conteo={}
for palabra in palabras:
 conteo[palabra]=conteo.get(palabra,0)+1
print(conteo)
# Out:
# {'gato': 1, 'gatos': 1, 'perros': 2, 'cuy': 2}

# %%
#ejercico  7:
contactos={"martin":5551234,"javier":123456,"leo":27483,"marcos":937836,"monica":37362,"Anthony":90292}
for nombre in list(contactos.keys()):
  if nombre.startswith("m"): #starswith : sirve para borrar palabras que empiecen con la letra que le especifiquemos
    del contactos[nombre]
print(contactos)
# Out:
# {'javier': 123456, 'leo': 27483, 'Anthony': 90292}

# %%
cant_premium = 0
cant_estandar = 0
print("--- CENTRO DE DISTRIBUCIÓN INDUSTRIAL ---")
while True:
    try:
        total_productos = int(input("¿Cuántos productos desea registrar?: "))
        if total_productos > 0:
            break
        else:
            print("¡Cantidad inválida! Ingresa un entero positivo para continuar")
    except ValueError:
        print("¡Cantidad inválida! Ingresa un entero positivo para continuar")
for i in range(total_productos):
    print(f"\n--- Registro del Producto {i + 1} de {total_productos} ---")
    while True:
        sku = input("Código SKU: ").strip()
        if len(sku) >= 6 and " " not in sku:
            break
        else:
            print("Error: El SKU debe tener al menos 6 caracteres y no incluir espacios")
    while True:
        try:
            valor_unitario = int(input("Valor Unitario: "))
            if valor_unitario > 0:
                break
            else:
                print("¡Error de valoración! Ingresa un número entero positivo para el valor unitario")
        except ValueError:
            print("¡Error de valoración! Ingresa un número entero positivo para el valor unitario")
    if valor_unitario >= 10000:
        cant_premium += 1
    else:
        cant_estandar += 1
print(" *** RESUMEN DEL REGISTRO DETALLADO *** ")
print("***************************************")
print(f" El almacen cuenta con un total de {total_productos} producto/s regitrados :")
print(f"Productos Premium: {cant_premium}")
print(f"Productos Estándar: {cant_estandar}")
print("DISTRIBUCION LISTA!!! SIUUUU!!!")
print("***************************************")
# Out:
# --- CENTRO DE DISTRIBUCIÓN INDUSTRIAL ---
# ¿Cuántos productos desea registrar?: 2
#
# --- Registro del Producto 1 de 2 ---
# Código SKU: NJASJE3
# Valor Unitario: 30000
#
# --- Registro del Producto 2 de 2 ---
# Código SKU: JSDA3
# Error: El SKU debe tener al menos 6 caracteres y no incluir espacios
# Código SKU: JSJJKWS1
# Valor Unitario: 2000
#  *** RESUMEN DEL REGISTRO DETALLADO ***
# ***************************************
#  El almacen cuenta con un total de 2 producto/s regitrados :
# Productos Premium: 1
# Productos Estándar: 1
# DISTRIBUCION LISTA!!! SIUUUU!!!
# ***************************************

# %%
cupos_disponibles = 30
total_ingresos = 0
print("¡Bienvenido al sistema de gestión de cupos del Estacionamiento Corporativo!\n")
while True:
    print("--- MENÚ PRINCIPAL ---")
    print("1. Cupos disponibles")
    print("2. Registrar vehículo")
    print("3. Retirar vehículo")
    print("4. Historial de ocupaciones")
    print("5. Salir")
    opcion = input("Seleccione una opción (1-5): ").strip()
    print("-" * 30)
    if opcion == "1":
        print(f"Cantidad actual de cupos disponibles: {cupos_disponibles}")
    elif opcion == "2":
        if cupos_disponibles == 0:
            print("No hay capacidad disponible en el estacionamiento")
        else:
            while True:
                try:
                    cantidad = int(input("Ingrese la cantidad de cupos a registrar: "))
                    if cantidad <= 0:
                        print("Error: La cantidad no puede ser menor o igual a 0.")
                    elif cantidad > cupos_disponibles:
                        print(f"Error: No puede superar la cantidad de cupos disponibles ({cupos_disponibles})")
                    else:
                        cupos_disponibles -= cantidad
                        total_ingresos += cantidad
                        print(f"Registro exitoso. Se ocuparon {cantidad} cupos.\n")
                        break
                except ValueError:
                    print("Por favor, ingrese un número entero válido.")
    elif opcion == "3":
        cupos_ocupados = 30 - cupos_disponibles
        if cupos_ocupados == 0:
            print("El estacionamiento está vacío , no hay vehículos para retirar.")
        else:
            while True:
                try:
                    cantidad = int(input("Ingrese la cantidad de vehículos a retirar: "))
                    if cantidad <= 0:
                        print("Error: La cantidad debe ser mayor a 0")
                    elif cantidad > cupos_ocupados:
                        print(f"Error: No puede superar la capacidad máxima ocupada actualmente ({cupos_ocupados}).")
                    else:
                        cupos_disponibles += cantidad
                        print(f"Retiro exitoso. Se liberaron {cantidad} cupos.")
                        break
                except ValueError:
                    print("Por favor, ingrese un número entero válido.")
    elif opcion == "4":
        print(f"Total de vehículos registrados durante la sesión: {total_ingresos}")
    elif opcion == "5":
        print("Gracias por utilizar nuestro software, hasta la próxima.")
        break

    else:
        print("Opción inválida. Por favor, elija un número del 1 al 5")
# Out:
# ¡Bienvenido al sistema de gestión de cupos del Estacionamiento Corporativo!
#
# --- MENÚ PRINCIPAL ---
# 1. Cupos disponibles
# 2. Registrar vehículo
# 3. Retirar vehículo
# 4. Historial de ocupaciones
# 5. Salir
# Seleccione una opción (1-5): 1
# ------------------------------
# Cantidad actual de cupos disponibles: 30
# --- MENÚ PRINCIPAL ---
# 1. Cupos disponibles
# 2. Registrar vehículo
# 3. Retirar vehículo
# 4. Historial de ocupaciones
# 5. Salir
# Seleccione una opción (1-5): 2
# ------------------------------
# Ingrese la cantidad de cupos a registrar: 1
# Registro exitoso. Se ocuparon 1 cupos.
#
# --- MENÚ PRINCIPAL ---
# 1. Cupos disponibles
# 2. Registrar vehículo
# 3. Retirar vehículo
# 4. Historial de ocupaciones
# 5. Salir
# Seleccione una opción (1-5): 3
# ------------------------------
# Ingrese la cantidad de vehículos a retirar: 1
# Retiro exitoso. Se liberaron 1 cupos.
# --- MENÚ PRINCIPAL ---
# 1. Cupos disponibles
# 2. Registrar vehículo
# 3. Retirar vehículo
# ...
